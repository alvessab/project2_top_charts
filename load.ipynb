# %%
import pandas as pd
from sqlalchemy import inspect, create_engine

# %%
HOSTNAME = "localhost"
PORT = 5432
DATABASE = "top_charts"
USERNAME = "postgres"
PASSWORD = "password"

path = f'postgresql+psycopg2://{USERNAME}:{PASSWORD}@{HOSTNAME}:{PORT}/{DATABASE}'
engine = create_engine(path)

# %%
inspector = inspect(engine)

for table in inspector.get_table_names():
    columns = inspector.get_columns(table)
    print(table)
    print()
    for column in columns:
        print(column["name"], column["type"])
    
    # or put it as a dataframe
    display(pd.DataFrame(columns))
    
    print()
# Out:
# artist
#
# artist_ID INTEGER
# artist_name VARCHAR(500)
# lastUpdate TIMESTAMP
#           name          type  nullable         default  autoincrement comment
# 0    artist_ID       INTEGER     False            None          False    None
# 1  artist_name  VARCHAR(500)     False            None          False    None
# 2   lastUpdate     TIMESTAMP     False  LOCALTIMESTAMP          False    None
# song
#
# song_ID INTEGER
# artist_ID INTEGER
# album_ID INTEGER
# song_name VARCHAR(500)
# song_length VARCHAR(10)
# lastUpdate TIMESTAMP
#           name          type  nullable         default  autoincrement comment
# 0      song_ID       INTEGER     False            None          False    None
# 1    artist_ID       INTEGER      True            None          False    None
# 2     album_ID       INTEGER      True            None          False    None
# 3    song_name  VARCHAR(500)     False            None          False    None
# ...

# %%
#load artist
artist_csv = pd.read_csv("final_csvs/artists.csv") 

artist_csv.to_sql(name='artist', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# DependentObjectsStillExist: cannot drop table artist because other objects depend on it
# DETAIL:  constraint fk_song_artist_ID on table song depends on table artist
# ...

# %%
#extract data
artist_df= pd.read_sql("select * from artist;", con=engine)
artist_df.head()
# Out:
#    artist_ID                                        artist_name  \
# 0          1  4*TOWN (From Disney and Pixar’s Turning Red), ...
# 1          2                                            42 Dugg
# 2          3                                              Adele
# 3          4                     AnnenMayKantereit, Giant Rooks
# 4          5                                     Arctic Monkeys
#
#                   lastUpdate
# 0 2022-03-21 21:23:32.005269
# 1 2022-03-21 21:23:32.005269
# 2 2022-03-21 21:23:32.005269
# 3 2022-03-21 21:23:32.005269
# 4 2022-03-21 21:23:32.005269

# %%
#load provider
provider_csv = pd.read_csv("final_csvs/provider.csv") 

provider_csv.to_sql(name='provider', con=engine, if_exists='replace', index=False)

# %%
#extract data
provider_df= pd.read_sql("select * from provider;", con=engine)
provider_df.head()

# %%
#load album
album_csv = pd.read_csv("final_csvs/albums.csv") 
album_csv.to_sql(name='album', con=engine, if_exists='replace', index=False)

# %%
#extract data
album_df= pd.read_sql("select * from album;", con=engine)
album_df

# %%
album_df.loc[album_df.artist_ID >=1 ]

# %%
#load song
song_csv = pd.read_csv("final_csvs/songs.csv") 
song_csv.to_sql(name='song', con=engine, if_exists='replace', index=False)

# %%
#extract data
songs_df= pd.read_sql("select * from song;", con=engine)
songs_df.head()
